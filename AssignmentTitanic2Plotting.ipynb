# %% [markdown]
# ### Titanic Plotting
# - Load data generated previously from 'titanic_filtered.csv'
# - plot histogram of ages of people
# - plot no of people in each pclass on bar chart
#
#
# - plot a horizontal bar-chart depicting the ratio of males to females
# - plot a bar-chart depicting the ratio of male-survived, female-survived, male-dead, female-dead.
# - plot a stacked bar chart of number of male-survived,dead and female-survived, dead.
# - plot stacked bar of survived with different pclass in same bar.
#
#
# - plot box plot of ages of survived vs not-survived
# - plot scatter plot of ages vs survived.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('titanic_filtered.csv')

# %%
# plot histogram of ages of people(
plt.figure(figsize = (16,5))
plt.hist(df.age, bins = 20)

df.age.plot(kind = 'hist')

# %%
res = df.pclass.value_counts()
res = res.sort_index()
print(res)
plt.bar(res.index.astype('str'), res.values)
plt.show()


res.plot(kind ='bar')

# %%
# plot a bar-chart depicting the ratio of males to females
res = df.gender.value_counts()
print(res)
plt.barh(res.index, res.values)
plt.show()
res.plot(kind='barh')
# Out:
# male      658
# female    388
# Name: gender, dtype: int64

# %%
# plot a bar-chart depicting the ratio of male-survived, female-survived, male-dead, female-dead.

grp = df.groupby(by =['gender','survived'])
grp.gender.count().plot(kind = 'bar')

# %%
# plot a stacked bar chart of number of male-survived,dead and female-survived, dead.

grp = df.groupby(by =['gender','survived'])

counts = grp.age.count()
print(counts.index)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-10b7bb52d7b0> in <module>
#       4
#       5 counts = grp.age.count()
# ----> 6 print(counts.index.flatten())
#
# AttributeError: 'MultiIndex' object has no attribute 'flatten'

# %%
# plot stacked bar of survived with different pclass in same bar

# %%
# plot box plot of ages of survived vs not-survived
plt.boxplot(df.age)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x284cf706dd8>,
#   <matplotlib.lines.Line2D at 0x284cf706eb8>],
#  'caps': [<matplotlib.lines.Line2D at 0x284cf7124a8>,
#   <matplotlib.lines.Line2D at 0x284cf7127f0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x284cf7069e8>],
#  'medians': [<matplotlib.lines.Line2D at 0x284cf712b38>],
#  'fliers': [<matplotlib.lines.Line2D at 0x284cf712e80>],
#  'means': []}

# %%
# plot scatter plot of ages vs survived.
